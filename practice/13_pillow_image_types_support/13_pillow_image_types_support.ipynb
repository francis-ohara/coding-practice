# %% [markdown]
# Task: Test whether the IPython.display module has difficulty displaying file types other than JPEG

# %%
from PIL import Image
from IPython.display import display


image = Image.open("image.png")
display(image)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PycharmProjects/python-practice/venv/lib/python3.11/site-packages/PIL/JpegImagePlugin.py:639, in _save(im, fp, filename)
#     638 try:
# --> 639     rawmode = RAWMODE[im.mode]
#     640 except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~/PycharmProjects/python-practice/venv/lib/python3.11/site-packages/PIL/Image.py:643, in Image._repr_image(self, image_format, **kwargs)
#     642 try:
# --> 643     self.save(b, image_format, **kwargs)
#     644 except Exception as e:
#
# File ~/PycharmProjects/python-practice/venv/lib/python3.11/site-packages/PIL/Image.py:2413, in Image.save(self, fp, format, **params)
#    2412 try:
# -> 2413     save_handler(self, fp, filename)
# ...

# %% [markdown]
# # My Hypothesis is indeed correct.
# Jupyter Notebooks, specifically Jupyter Notebook's IPython.display's `display()` method throws an error whenever the file type of the image being displayed is not JPG (or at least when it's PNG).
# Regardless of the value error thrown, it proceeds to display the image.
